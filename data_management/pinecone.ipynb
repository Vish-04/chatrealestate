# %%
import os
from dotenv import load_dotenv
import boto3
from pinecone import Pinecone, ServerlessSpec
import pandas as pd
load_dotenv()
aws_access_key_id = os.getenv('AWS_ACCESS_KEY')
aws_secret_access_key = os.getenv('AWS_SECRET_KEY')
print(aws_access_key_id)
print(aws_secret_access_key)
client = boto3.resource('dynamodb', region_name='us-west-1', aws_access_key_id = aws_access_key_id, aws_secret_access_key = aws_secret_access_key)
# Initialize a session using Amazon DynamoDB

table = client.Table('dre_listings')
# Scan the table and filter for all data
# Out:
# AKIA3FLD3PD5L2ISQFMM
# 9nJVIXL6Lu/2f/oCu8bMx5eBCQvrWKM/YOL2G+1m

# %%
"""import time
import botocore.exceptions

# Function to scan the table and handle pagination with exponential backoff
def scan_table(table):
    data = []
    last_evaluated_key = None
    retries = 0
    max_retries = 9

    while True:
        try:
            if last_evaluated_key:
                response = table.scan(ExclusiveStartKey=last_evaluated_key)
            else:
                response = table.scan()
            
            data.extend(response['Items'])
            
            last_evaluated_key = response.get('LastEvaluatedKey', None)
            if not last_evaluated_key:
                break

        except botocore.exceptions.ClientError as e:
            if e.response['Error']['Code'] == 'ProvisionedThroughputExceededException':
                if retries < max_retries:
                    retries += 1
                    wait_time = 2 ** retries
                    print(f"ProvisionedThroughputExceededException: retrying in {wait_time} seconds...")
                    time.sleep(wait_time)
                else:
                    print("Max retries reached. Exiting.")
                    break
            else:
                raise

    return data

# Scan the table and retrieve all data
all_items = scan_table(table)"""
# Out:
# 'import time\nimport botocore.exceptions\n\n# Function to scan the table and handle pagination with exponential backoff\ndef scan_table(table):\n    data = []\n    last_evaluated_key = None\n    retries = 0\n    max_retries = 9\n\n    while True:\n        try:\n            if last_evaluated_key:\n                response = table.scan(ExclusiveStartKey=last_evaluated_key)\n            else:\n                response = table.scan()\n            \n            data.extend(response[\'Items\'])\n            \n            last_evaluated_key = response.get(\'LastEvaluatedKey\', None)\n            if not last_evaluated_key:\n                break\n\n        except botocore.exceptions.ClientError as e:\n            if e.response[\'Error\'][\'Code\'] == \'ProvisionedThroughputExceededException\':\n                if retries < max_retries:\n                    retries += 1\n                    wait_time = 2 ** retries\n                    print(f"ProvisionedThroughputExceededException: retrying 
# ...

# %%
all_items = pd.read_csv('scan.csv')

# %%
all_items.fillna("None", inplace=True)
# Out:
# C:\Users\nitin_b\AppData\Local\Temp\ipykernel_52120\86750416.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'None' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   all_items.fillna("None", inplace=True)

# %%
all_items.head()
# Out:
#    Unnamed: 0                                   parking_features  \
# 0           0  Uncovered Parking Spaces 2+, RV Storage, Boat ...
# 1           1  Attached, Garage Door Opener, Guest Parking Av...
# 2           2                          Covered, Other, Uncovered
# 3           3                                           Attached
# 4           4             Uncovered Parking Spaces 2+, No Garage
#
#                 architectural_style                                flooring  \
# 0                       Mid-Century  Tile, Simulated Wood, Laminate, Carpet
# 1  Contemporary, Ranch, Traditional                      Carpet, Tile, Wood
# 2                              None                          Linoleum/Vinyl
# 3                              None              Tile, Wood, Linoleum/Vinyl
# 4                          Bungalow                Wood, Linoleum, Laminate
#
#                   window_features    listing_agent_name year_built  \
# ...

# %%
all_items.drop('Unnamed: 0',axis=1,inplace=True)

# %%
all_items.columns
# Out:
# Index(['parking_features', 'architectural_style', 'flooring',
#        'window_features', 'listing_agent_name', 'year_built', 'roof',
#        'area/district', 'lot_features', 'heating',
#        'elementary_school_district', 'county', 'highlights_text', 'appliances',
#        'laundry_features', 'master_bedroom_features', 'association_features',
#        'kitchen_features', 'dining_room_features', 'property_description',
#        'school_district_(county)', 'living_room_features',
#        'property_condition', 'listing_office_name', 'patio_and_porch_features',
#        'pool', 'middle_or_junior_school_district', 'master_bathroom_features',
#        'senior_high_school_district', 'remodeled/updated',
#        'listings_detail_label', 'interior_features', 'bath_features',
#        'cooling', 'combined_text'],
#       dtype='object')

# %%
items=pd.DataFrame(all_items)

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2386 entries, 0 to 2385
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   parking_features                  2386 non-null   object
#  1   architectural_style               2386 non-null   object
#  2   flooring                          2386 non-null   object
#  3   window_features                   2386 non-null   object
#  4   listing_agent_name                2386 non-null   object
#  5   year_built                        2386 non-null   object
#  6   roof                              2386 non-null   object
#  7   area/district                     2386 non-null   object
#  8   lot_features                      2386 non-null   object
#  9   heating                           2386 non-null   object
#  10  elementary_school_district        2386 non-null   object
# ...

# %%
items.head()
# Out:
#                                     parking_features  \
# 0  Uncovered Parking Spaces 2+, RV Storage, Boat ...
# 1  Attached, Garage Door Opener, Guest Parking Av...
# 2                          Covered, Other, Uncovered
# 3                                           Attached
# 4             Uncovered Parking Spaces 2+, No Garage
#
#                 architectural_style                                flooring  \
# 0                       Mid-Century  Tile, Simulated Wood, Laminate, Carpet
# 1  Contemporary, Ranch, Traditional                      Carpet, Tile, Wood
# 2                              None                          Linoleum/Vinyl
# 3                              None              Tile, Wood, Linoleum/Vinyl
# 4                          Bungalow                Wood, Linoleum, Laminate
#
#                   window_features    listing_agent_name year_built  \
# 0                  Dual Pane Full  Christopher Anderson     1954.0
# ...

# %%
items['highlights_text'][0]
# Out:
# '3 Bedrooms2 Bathrooms1000 sq ftStatus ActiveSingle FamilyMLS# 324032906'

# %%
items.columns
# Out:
# Index(['parking_features', 'architectural_style', 'flooring',
#        'window_features', 'listing_agent_name', 'year_built', 'roof',
#        'area/district', 'lot_features', 'heating',
#        'elementary_school_district', 'county', 'highlights_text', 'appliances',
#        'laundry_features', 'master_bedroom_features', 'association_features',
#        'kitchen_features', 'dining_room_features', 'property_description',
#        'school_district_(county)', 'living_room_features',
#        'property_condition', 'listing_office_name', 'patio_and_porch_features',
#        'pool', 'middle_or_junior_school_district', 'master_bathroom_features',
#        'senior_high_school_district', 'remodeled/updated',
#        'listings_detail_label', 'interior_features', 'bath_features',
#        'cooling', 'combined_text'],
#       dtype='object')

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2386 entries, 0 to 2385
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   parking_features                  2386 non-null   object
#  1   architectural_style               2386 non-null   object
#  2   flooring                          2386 non-null   object
#  3   window_features                   2386 non-null   object
#  4   listing_agent_name                2386 non-null   object
#  5   year_built                        2386 non-null   object
#  6   roof                              2386 non-null   object
#  7   area/district                     2386 non-null   object
#  8   lot_features                      2386 non-null   object
#  9   heating                           2386 non-null   object
#  10  elementary_school_district        2386 non-null   object
# ...

# %%
items['combined_text'][0]
# Out:
# "parking_features: Uncovered Parking Spaces 2+, RV Storage, Boat Storage architectural_style: Mid-Century flooring: Tile, Simulated Wood, Laminate, Carpet window_features: Dual Pane Full listing_agent_name: Christopher Anderson year_built: 1954 roof: Flat, Bitumen bathrooms: 2 area/district: None lot_features: Street Lights, Storm Drain, Shape Regular, Pond Year Round, Landscape Front, Landscape Back, Curb(s)/Gutter(s), Auto Sprinkler F&R heating: Central elementary_school_district: None county: Solano highlights_text: 3 Bedrooms2 Bathrooms1000 sq ftStatus ActiveSingle FamilyMLS# 324032906 appliances: Plumbed For Ice Maker, Microwave, Hood Over Range, Free Standing Refrigerator, Free Standing Gas Range, Free Standing Gas Oven, Dishwasher laundry_features: Washer Included, Inside Room, Dryer Included master_bedroom_features: Walk-In Closet association_features: None kitchen_features: Granite Counter half_bathrooms: 0 dining_room_features: Dining/Living Combo #_of_fireplaces: 0 total_p
# ...

# %%
filtered_items = items[['combined_text','listings_detail_label']]

# %%
from sentence_transformers import SentenceTransformer
from pinecone.grpc import PineconeGRPC as Pinecone
from pinecone import ServerlessSpec
import os
from dotenv import load_dotenv

load_dotenv()

# Initialize the sentence transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')



# Create a dictionary to store embeddings
embeddings_dict = {}

# Iterate over filtered_items to generate embeddings
for index, row in filtered_items.iterrows():
    embedding = model.encode(row['combined_text'])
    embeddings_dict[row['listings_detail_label']] = embedding

# %%
# Initialize Pinecone
pinecone = Pinecone(api_key=os.getenv('PINECONE_API_KEY'))


# Create an index
index_name = 'real-estate-listings'
print(pinecone.list_indexes())
"""if index_name not in pinecone.list_indexes():
    pinecone.create_index(index_name, dimension=384,metric="cosine",  spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    ) )  # 384 is the dimension of 'all-MiniLM-L6-v2' embeddings"""

index = pinecone.Index(index_name)
# Out:
# {'indexes': [{'deletion_protection': 'disabled',
#               'dimension': 384,
#               'host': 'real-estate-listings-p47w3od.svc.aped-4627-b74a.pinecone.io',
#               'metric': 'cosine',
#               'name': 'real-estate-listings',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-east-1'}},
#               'status': {'ready': True, 'state': 'Ready'}}]}

# %%
def batch_upsert(index, vectors, batch_size=100):
    for i in range(0, len(vectors), batch_size):
        batch = vectors[i:i + batch_size]
        index.upsert(vectors=batch, namespace="ns1")

# Prepare data for upsert
to_upsert = []

for label, embedding in embeddings_dict.items():
    # Ensure embedding is a list of floats
    if isinstance(embedding, list):
        embedding = [float(x) for x in embedding]
    elif hasattr(embedding, 'tolist'):
        embedding = embedding.tolist()
    else:
        raise ValueError(f"Invalid embedding type for label {label}: {type(embedding)}")

    to_upsert.append({
        "id": label,
        "values": embedding,
        "metadata": {"listings_detail_label": label}
    })

print(to_upsert[0])

# Upsert data in batches
batch_upsert(index, to_upsert, batch_size=100)
# Out:
# {'id': '1172 1st St Fairfield, CA 94533', 'values': [0.017880922183394432, 0.010066956281661987, 0.003191983560100198, 0.05404822155833244, 0.049461424350738525, -0.006393452174961567, -0.03669494763016701, -0.03687369078397751, -0.11526110768318176, -0.020748302340507507, 0.044676151126623154, -0.08585035800933838, -0.024921787902712822, -0.00427147326990962, -0.01874886453151703, 0.03823181241750717, 0.05663203448057175, 0.023776980116963387, 0.0018487087218090892, 0.04394175857305527, -0.006504443008452654, 0.058082010596990585, 0.028672777116298676, -0.0837671235203743, 0.000919115322176367, 0.12077505141496658, -0.022666096687316895, 0.06128598749637604, -0.053306929767131805, -0.016560478135943413, 0.02000470831990242, 0.06887529045343399, 0.040519848465919495, 0.004161440767347813, 0.2013237327337265, -0.004566565155982971, 0.013474060222506523, 0.011900171637535095, 0.029890157282352448, -0.024950740858912468, -0.029665326699614525, -0.07090287655591965, 0.02999117039144039, 
# ...

# %%
query='I want to know all the places where I can park an RV'

encoded_query = model.encode(query)


results=index.query(
    namespace="ns1",
    vector=encoded_query,
    top_k=20,
    include_values=True,
    include_metadata=True,
)

# %%
results
# Out:
# {'matches': [{'id': '4749 Racetrack Cir Rocklin, CA 95677',
#               'metadata': {'listings_detail_label': '4749 Racetrack Cir '
#                                                     'Rocklin, CA 95677'},
#               'score': 0.58485705,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': [0.045673575,
#                          0.022868307,
#                          0.0047480464,
#                          0.0013032238,
#                          0.022730809,
#                          0.026486408,
#                          0.007262065,
#                          -0.040903553,
#                          -0.037298787,
#                          -0.010931777,
#                          -0.010033097,
#                          -0.010602489,
#                          0.041350808,
#                          -0.014511278,
#                          0.05072164,
#                          0.07905426,
#                          0.12420126,
# ...

# %%
def get_match_ids(results):
    return [match['id'] for match in results['matches']]

get_match_ids(results=results)
# Out:
# ['4749 Racetrack Cir Rocklin, CA 95677',
#  '149 Meadowbrook Ct Vallejo, CA 94591',
#  '1710 Misfeldt St Dixon, CA 95620',
#  '306 Abbey St Winters, CA 95694',
#  '4078 Harlington Cir El Dorado Hills, CA 95762',
#  '6105 Palm Dr Carmichael, CA 95608',
#  '617 Vendola Dr San Rafael, CA 94903',
#  '157 Kearney Wy Vacaville, CA 95687',
#  '100 South St #307 Sausalito, CA 94965',
#  '26 Peninsula Rd Belvedere, CA 94920',
#  '6111 Harlen Ct Sacramento, CA 95842',
#  '443 Melissa Ct Vacaville, CA 95687',
#  '6917 Speckle Wy Sacramento, CA 95842',
#  '8128 Molokai Wy Fair Oaks, CA 95628',
#  '5200 Mckinney Wy Carmichael, CA 95608',
#  '7617 Putman Rd Vacaville, CA 95688',
#  '1633 Calabria Wy Roseville, CA 95747',
#  '930 E 7th St Benicia, CA 94510',
#  '135 Shevelin Rd Novato, CA 94947',
#  '90 Oak Springs Dr Napa, CA 94558']
